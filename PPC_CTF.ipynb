# %% [markdown]
# <a href="https://colab.research.google.com/github/MyDearGreatTeacher/security_awareness/blob/master/PPC_CTF.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # alphabet

# %%
#!/usr/bin/env python3
import random
import string

print("===== Welcome to alphabet counter =====")
print("We got some alphabet to count")
print("Can you help us?")

for i in range(100):
    print("----- wave {}/100 -----".format(i + 1))
    ch = chr(ord('a') + random.randint(0, 25))
    text = ''.join([random.choice(string.ascii_lowercase) for _ in range(50)])
    print('How many {} in {}'.format(ch, text))
    x = int(input().strip())
    if not (x == text.count(ch)):
        exit(9)

print("CTF{m4rvel AGeNts 0F ShIE1d - 41pHab3t CouNter}")

# %% [markdown]
# ###  解答

# %%
#!/usr/bin/env python3
from pwn import *

r = remote('127.0.0.1', 20000)

r.recvlines(3)

for i in range(100):
    r.recvline()
    r.recvuntil('How many ')
    ch = r.recvn(1)
    r.recvuntil(' in ')
    text = r.recvline().strip()
    r.sendline(str(text.count(ch)))

r.interactive()

# %% [markdown]
# # apple shop

# %% [markdown]
# ###  解答

# %%
#!/usr/bin/env python3
from pwn import *
from base64 import b64encode

r = remote("127.0.0.1", 9999)

auth = bytes.fromhex("2ebf252b317a0b3a3f890218819ebd283da458c47378178343c70d43700ddfec")
coupon = b"Anr9Ecttjm\x80\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\x00\xf08X3kU8nKpP"

r.sendlineafter("> ", "1")
r.sendlineafter("coupon : ", b64encode(auth + coupon))
r.sendlineafter("> ", "4")
print(r.recvline())

# %% [markdown]
# ###  解答

# %% [markdown]
# ###  解答

# %% [markdown]
# ###  解答

# %% [markdown]
# ###  解答

# %% [markdown]
# ###  解答

# %% [markdown]
# ###  解答

# %% [markdown]
# ###  解答

# %% [markdown]
# ###  解答

# %% [markdown]
# ###  解答

# %% [markdown]
# ###  解答
